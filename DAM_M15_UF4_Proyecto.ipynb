# %%
#Primero instalamos seaborn con los comandos pip install --upgrade pip y pip install seaborn, 
#para poder importar estas bibliotecas. Importamos panda
#para trabajar con nuestra data, Matploit para hacer graficos y seaborn 
#para que nuestros graficos se vean mejor.
# %matplotlib inline
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns 
from google.colab import drive
#Importamos la libreria numpy y le ponemos el nombre de np
import numpy as npBB
import json
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Cargamos los data
dataframeBR = pd.read_csv("/content/drive/MyDrive/BigData/BR_youtube_trending_data.csv")
#dataframePrueba = pd.read_csv("/DatasetUS.csv", lineterminator='\n')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-2-2982f1907315> in <module>()
#       1 # Cargamos los data
# ----> 2 dataframeBR = pd.read_csv("/content/drive/MyDrive/BigData/BR_youtube_trending_data.csv")
#       3 #dataframePrueba = pd.read_csv("/DatasetUS.csv", lineterminator='\n')
#
# ...

# %%
dataframeBR.describe()

# %%
dataframeBR.head()

# %%
dataframeBR['Country']='BR'

# %%
dataframeBR.drop('description', axis=1, inplace=True)

# %%
id_to_category = {}

with open("/content/drive/MyDrive/BigData/BR_category_id.json","r") as f:
    id_data = json.load(f)
    for category in id_data["items"]:
        id_to_category[category["id"]] = category["snippet"]["title"]

id_to_category

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
type(dataframeBR["categoryId"][0])

# %%
dataframeBR["categoryId"] = dataframeBR["categoryId"].astype(str)

# %%
dataframeBR.insert(4, "category",dataframeBR["categoryId"].map(id_to_category))

# %%
dataframeBR[dataframeBR["video_id"] == "s9FH4rDMvds"]

# %%
dataframeBR.head()

# %%
dataframeBR.to_csv("DatasetBR2021.csv", index=False)

# %%
dataframeBR2021 = pd.read_csv("/content/drive/MyDrive/datasetLimpios/DatasetBR2021.csv")

# %%
dataframeBR2021.head()
# Out:
#       video_id  ... Country
# 0  s9FH4rDMvds  ...      BR
# 1  jbGRowa5tIk  ...      BR
# 2  3EfkCrXKZNs  ...      BR
# 3  gBjox7vn3-g  ...      BR
# 4  npoUGx7UW7o  ...      BR
#
# [5 rows x 17 columns]

# %%
dataframeUS2021 = pd.read_csv("/content/drive/MyDrive/datasetLimpios/DatasetUS2021.csv")

# %%
dataframeUS2021.head()
# Out:
#       video_id  ... Country
# 0  3C66w5Z0ixs  ...      US
# 1  M9Pmf9AB4Mo  ...      US
# 2  J78aPJ3VyNs  ...      US
# 3  kXLn3HkpjaA  ...      US
# 4  VIUo6yapDbc  ...      US
#
# [5 rows x 17 columns]

# %%
dataframeMX2021 = pd.read_csv("/content/drive/MyDrive/datasetLimpios/DatasetMX2021.csv")

# %%
 frames = [dataframeBR2021, dataframeUS2021, dataframeMX2021]

# %%
result = pd.concat(frames)

# %%
result[result["Country"] == "MX"]
# Out:
#           video_id  ... Country
# 0      SsWHMAhshPQ  ...      MX
# 1      JOaeND0xUNk  ...      MX
# 2      SV91jnGs--s  ...      MX
# 3      QgX0zn5nMyk  ...      MX
# 4      cKaM19oAwBM  ...      MX
# ...            ...  ...     ...
# 51994  9fyB-TMVjmk  ...      MX
# 51995  2geVBi0Id4A  ...      MX
# 51996  FQsSBrdub0o  ...      MX
# 51997  9-Q6KmP8Yds  ...      MX
# 51998  OnG7UjzUeJ4  ...      MX
#
# [51999 rows x 17 columns]

# %%
result.to_csv("DatasetCompleto2021.csv", index=False)

# %%
dataframeCompleto2021 = pd.read_csv("/content/drive/MyDrive/datasetLimpios/DatasetCompleto2021.csv")

# %%
dataframeCompleto2021[dataframeCompleto2021["Country"] == "MX"]
# Out:
#            video_id  ... Country
# 104384  SsWHMAhshPQ  ...      MX
# 104385  JOaeND0xUNk  ...      MX
# 104386  SV91jnGs--s  ...      MX
# 104387  QgX0zn5nMyk  ...      MX
# 104388  cKaM19oAwBM  ...      MX
# ...             ...  ...     ...
# 156378  9fyB-TMVjmk  ...      MX
# 156379  2geVBi0Id4A  ...      MX
# 156380  FQsSBrdub0o  ...      MX
# 156381  9-Q6KmP8Yds  ...      MX
# 156382  OnG7UjzUeJ4  ...      MX
#
# [51999 rows x 17 columns]

# %%
print(dataframeCompleto2021.shape)
# Out:
# (156383, 17)
